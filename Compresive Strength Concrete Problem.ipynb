# %%
cd /content/drive/MyDrive/AI_Assignments
# Out:
# /content/drive/MyDrive/AI_Assignments

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading data
dataset = pd.DataFrame(pd.read_csv('compresive_strength_concrete.csv'))

# %%
dataset.head()
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                      540.0  ...                                             79.99
# 1                                      540.0  ...                                             61.89
# 2                                      332.5  ...                                             40.27
# 3                                      332.5  ...                                             41.05
# 4                                      198.6  ...                                             44.30
#
# [5 rows x 9 columns]

# %%
#analyzing data
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Cement (component 1)(kg in a m^3 mixture)             1030 non-null   float64
#  1   Blast_Furnace_Slag                                    1030 non-null   float64
#  2   Fly_Ash                                               1030 non-null   float64
#  3   Water  (component 4)(kg in a m^3 mixture)             1030 non-null   float64
#  4   Superplasticizer                                      1030 non-null   float64
#  5   Coarse Aggregate  (component 6)(kg in a m^3 mixture)  1030 non-null   float64
#  6   Fine Aggregate (component 7)(kg in a m^3 mixture)     1030 non-null   float64
#  7   Age (day)                                             1030 non-null   int64
#  8   Concrete compressive strength(MPa, megapascals)       1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
dataset.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# count                                1030.000000  ...                                       1030.000000
# mean                                  281.167864  ...                                         35.817961
# std                                   104.506364  ...                                         16.705742
# min                                   102.000000  ...                                          2.330000
# 25%                                   192.375000  ...                                         23.710000
# 50%                                   272.900000  ...                                         34.445000
# 75%                                   350.000000  ...                                         46.135000
# max                                   540.000000  ...                                         82.600000
#
# [8 rows x 9 columns]

# %%
#check for null values
dataset.isna().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)               0
# Blast_Furnace_Slag                                      0
# Fly_Ash                                                 0
# Water  (component 4)(kg in a m^3 mixture)               0
# Superplasticizer                                        0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)    0
# Fine Aggregate (component 7)(kg in a m^3 mixture)       0
# Age (day)                                               0
# Concrete compressive strength(MPa, megapascals)         0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)               0
# Blast_Furnace_Slag                                      0
# Fly_Ash                                                 0
# Water  (component 4)(kg in a m^3 mixture)               0
# Superplasticizer                                        0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)    0
# Fine Aggregate (component 7)(kg in a m^3 mixture)       0
# Age (day)                                               0
# Concrete compressive strength(MPa, megapascals)         0
# dtype: int64

# %%
dataset[dataset.duplicated() == True]
# Out:
#      Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 77                                       425.0  ...                                             33.40
# 80                                       425.0  ...                                             33.40
# 86                                       362.6  ...                                             35.30
# 88                                       362.6  ...                                             35.30
# 91                                       362.6  ...                                             35.30
# 100                                      425.0  ...                                             49.20
# 103                                      425.0  ...                                             49.20
# 109                                      362.6  ...                                             55.90
# 111                                      362.6  ...                                             55.90
# 123                                      425.0  ...                                             60.29
# 126                                      425.0  ...                                             60.29
# 132                                      362.6  ...                                             71.30
# 134                                      362.6  ...                                             71.30
# 137                                      362.6  ...                                             71.30
# 146                                      425.0  ...                                             64.30
# 149                                      425.0  ...                                             64.30
# 155                                      362.6  ...                                             77.30
# 157                                      362.6  ...                                             77.30
# 160                                      362.6  ...                                             77.30
# 169                                      425.0  ...                                             65.20
# 172                                      425.0  ...                                             65.20
# 177                                      362.6  ...                                             79.30
# 179                                      362.6  ...                                             79.30
# 182                                      362.6  ...                                             79.30
# 809                                      252.0  ...                                             19.69
#
# [25 rows x 9 columns]

# %%
#analyzing the columns
dataset.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)', 'Blast_Furnace_Slag',
#        'Fly_Ash', 'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
dataset.head()
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                      540.0  ...                                             79.99
# 1                                      540.0  ...                                             61.89
# 2                                      332.5  ...                                             40.27
# 3                                      332.5  ...                                             41.05
# 4                                      198.6  ...                                             44.30
#
# [5 rows x 9 columns]

# %%
blast_mean = np.mean(dataset.Blast_Furnace_Slag)
fly_mean = np.mean(dataset.Fly_Ash)
superplastic_mean = np.mean(dataset.Superplasticizer)

# %%
dataset.Blast_Furnace_Slag=dataset.Blast_Furnace_Slag.mask(dataset.Blast_Furnace_Slag==0).fillna(blast_mean)

# %%
dataset.Fly_Ash=dataset.Fly_Ash.mask(dataset.Fly_Ash==0).fillna(fly_mean)

# %%
dataset.Superplasticizer=dataset.Superplasticizer.mask(dataset.Superplasticizer==0).fillna(superplastic_mean)

# %%
dataset
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                         540.0  ...                                             79.99
# 1                                         540.0  ...                                             61.89
# 2                                         332.5  ...                                             40.27
# 3                                         332.5  ...                                             41.05
# 4                                         198.6  ...                                             44.30
# ...                                         ...  ...                                               ...
# 1025                                      276.4  ...                                             44.28
# 1026                                      322.2  ...                                             31.18
# 1027                                      148.5  ...                                             23.70
# 1028                                      159.1  ...                                             32.77
# 1029                                      260.9  ...                                             32.40
#
# [1030 rows x 9 columns]

# %%
y = dataset['Concrete compressive strength(MPa, megapascals) ']

# %%
x = dataset.drop(columns='Concrete compressive strength(MPa, megapascals) ')

# %%
x
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  ...  Age (day)
# 0                                         540.0  ...         28
# 1                                         540.0  ...         28
# 2                                         332.5  ...        270
# 3                                         332.5  ...        365
# 4                                         198.6  ...        360
# ...                                         ...  ...        ...
# 1025                                      276.4  ...         28
# 1026                                      322.2  ...         28
# 1027                                      148.5  ...         28
# 1028                                      159.1  ...         28
# 1029                                      260.9  ...         28
#
# [1030 rows x 8 columns]

# %%
# Split dataset for training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#      Cement (component 1)(kg in a m^3 mixture)  ...  Age (day)
# 196                                      194.7  ...         28
# 631                                      325.0  ...          7
# 81                                       318.8  ...          3
# 526                                      359.0  ...          3
# 830                                      162.0  ...         28
# ..                                         ...  ...        ...
# 87                                       286.3  ...          3
# 330                                      246.8  ...         14
# 466                                      190.3  ...        100
# 121                                      475.0  ...         28
# 860                                      314.0  ...         28
#
# [721 rows x 8 columns]

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2)

# %%
X_train.shape
# Out:
# (576, 8)

# %%
X_val.shape
# Out:
# (145, 8)

# %%
X_test.shape
# Out:
# (309, 8)

# %%
# Data Normalization
mean = X_train.mean(axis=0)
std = X_train.std(axis=0)

X_train -= mean
X_train /= std

X_test -= mean
X_test /= std


X_val -= mean
X_val /= std

# %%
# Let's go
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
network = Sequential()

# %%
network.add(layers.Dense(6, activation='relu', input_shape=(X_train.shape[1],)))
network.add(layers.Dense(4, activation='relu'))
network.add(layers.Dense(1))

# %%
network.compile(optimizer='adam', loss='mse', metrics='mae')

# %%
history = network.fit(X_train, Y_train, batch_size=30, verbose=0, epochs=200, validation_data=(X_val, Y_val))

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, 201)

# %%
print('Training Loss: ' + str(train_loss[-1]))
print('*'*20)
print('Validation Loss' + str(val_loss[-1]))
# Out:
# Training Loss: 86.18317413330078
# ********************
# Validation Loss104.29121398925781

# %%
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Val loss')
plt.title('Train and Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
mae_train = history.history['mae']
mae_val= history.history['val_mae']

# %%
print('Training Loss: ' + str(mae_train[-1]))
print('*'*20)
print('Validation Loss' + str(mae_val[-1]))
# Out:
# Training Loss: 7.35270357131958
# ********************
# Validation Loss7.681028366088867

# %%
plt.plot(epochs, mae_train, label='Training MAE')
plt.plot(epochs, mae_val, label='Val MAE')
plt.title('Train and Val MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
prediction = network.predict(X_test)

# %%
network.evaluate(X_test, Y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 95.5885 - mae: 7.7690
# [95.58846282958984, 7.768993377685547]

# %%
prediction.shape
# Out:
# (309, 1)

# %%
prediction=prediction.reshape(309)

# %%
output = pd.DataFrame({'Actual': Y_test})

# %%
output['prediction'] = prediction

# %%
output.reset_index(inplace=True)

# %%
output['Absolute Error'] = np.abs(output['prediction'] - output['Actual'])

# %%
output
# Out:
#      index  Actual  prediction  Absolute Error
# 0       31   52.91   59.684105        6.774105
# 1      109   55.90   51.022194        4.877806
# 2      136   74.50   60.418835       14.081165
# 3       88   35.30   49.911808       14.611808
# 4      918   10.54   17.530466        6.990466
# ..     ...     ...         ...             ...
# 304    250   24.92   24.058319        0.861681
# 305    377   36.30   26.341417        9.958583
# 306    615   32.33   35.934204        3.604204
# 307      9   39.29   37.755630        1.534370
# 308    357   66.82   34.226532       32.593468
#
# [309 rows x 4 columns]

# %%
#end
